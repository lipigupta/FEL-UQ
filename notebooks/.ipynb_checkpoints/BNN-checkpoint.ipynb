# %%
# %load_ext autoreload
# %autoreload 2

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from blitz.modules import BayesianLinear
from blitz.utils import variational_estimator

import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import pandas as pd
import time
import basicFunctions as bf
import pickle

### Colorblind friendly colors:

colors = [[0,0,0], [230/255,159/255,0], [86/255,180/255,233/255], [0,158/255,115/255],
          [213/255,94/255,0], [0,114/255,178/255]]


import matplotlib.style
import matplotlib as mpl
mpl.style.use('fivethirtyeight')
font = {'family' : 'sans-serif',
        'weight' : 'bold',
        'size'   : 15}
mpl.rc('font', **font)


import BNNUtils as bu

import os
import sys

path = os.getcwd()

# %%
PLOTTING = True

# %%
@variational_estimator
class BayesianRegressor(nn.Module):
    def __init__(self, input_dim, output_dim):
        super().__init__()
        #self.linear = nn.Linear(input_dim, output_dim)
        self.blinear1 = BayesianLinear(input_dim, 80)
        self.blinear2 = BayesianLinear(80, 60)
        self.blinear3 = BayesianLinear(60, 50)
        self.blinear4 = BayesianLinear(50, 40)
        self.blinear5 = BayesianLinear(40, 20)
        self.blinear6 = BayesianLinear(20, 20)
        self.blinear7 = BayesianLinear(20, 20)
        self.blinear8 = BayesianLinear(20, output_dim)
        
    def forward(self, x):
        x_=self.blinear1(x)
        x_=F.relu(x_)
        x_=self.blinear2(x_)
        x_=F.relu(x_)
        x_=self.blinear3(x_)
        x_=F.relu(x_)
        x_=self.blinear4(x_)
        x_=F.relu(x_)
        x_=self.blinear5(x_)
        x_=F.relu(x_)
        x_=self.blinear6(x_)
        x_=F.relu(x_)
        x_=self.blinear7(x_)
        x_=F.relu(x_)
        return self.blinear8(x_)   

def evaluate_regression(regressor,
                        X,
                        y,
                        samples = 100,
                        std_multiplier = 2):
    preds = [regressor(X) for i in range(samples)]
    preds = torch.stack(preds)
    means = preds.mean(axis=0)
    stds = preds.std(axis=0)
    ci_upper = means + (std_multiplier * stds)
    ci_lower = means - (std_multiplier * stds)
    ic_acc = (ci_lower <= y) * (ci_upper >= y)
    ic_acc = ic_acc.float().mean()
    return ic_acc, (ci_upper >= y).float().mean(), (ci_lower <= y).float().mean()


def calc_mse_and_mae(meas, pred):
    mse = np.mean((meas - pred)**2)
    mae = np.mean(np.abs(meas-pred))
    return mse, mae

# %%
PATH = path+"/../datasets/"
NAME = "compiled_"
inputdf = pd.read_csv(PATH + NAME +'X.csv') 
outputdf = pd.read_csv(PATH + NAME + 'Y.csv')

# %%
variable_names = inputdf.columns[1:]

output_names = outputdf.columns[1:]

view = False
name_dict = {}
## View the names and indicies of each variable
for i, v in enumerate(variable_names):
    name_dict[v] = i
    if view:
        print(i, v)

# %%
input_data = inputdf.to_numpy()
output_data = outputdf.to_numpy()
## Removing "index column"
output_data = output_data[:,1]


print("Original shape of data, before cutting out extraneous data or selected HXR samples:")
print("Input values: " + str(np.shape(input_data)))
print("Output values: " + str(np.shape(output_data)))

mask = np.where(np.logical_and(output_data>0, output_data<5))

## apply mask and cut out "index column"

removed_perc = 100*(np.shape(output_data)[0] - np.shape(output_data[mask])[0])/(np.shape(output_data)[0] )

input_data = input_data[mask[0], 1:]
output_data = output_data[mask]

print("Removed {:2f}% of full dataset, eliminating extraneous values".format(removed_perc))



print("Final shape of data, after cutting out extraneous data:")
print("Input values: " + str(np.shape(input_data)))
print("Output values: " + str(np.shape(output_data)))


if PLOTTING:
    plt.figure(figsize = (12,6))
    plt.title("Histogram of Output Data")
    plt.xlabel("Pulse Energy (mJ)")
    plt.hist(output_data, 100, facecolor = colors[0], alpha = 0.5)
    plt.show()
# Out:
# Original shape of data, before cutting out extraneous data or selected HXR samples:
# Input values: (286923, 77)
# Output values: (286923,)
# Removed 0.646515% of full dataset, eliminating extraneous values
# Final shape of data, after cutting out extraneous data:
# Input values: (285068, 76)
# Output values: (285068,)

# %%
# input_data = np.load("10perc_inputs.npy")
# out_data = np.load("10perc_outputs.npy")

# n = np.shape(input_data)[0]

# if PLOTTING:
#     plt.figure(figsize = (26, 5))
#     plt.title("Unfiltered Data")
#     plt.ylabel("Pulse Energy")
#     plt.plot(output_data)
#     plt.show()

#     plt.figure(figsize = (26, 5))
#     plt.title("Filtered, Rejected 20% above/below moving mean (removed 10% of original dataset)")
#     plt.ylabel("Pulse Energy")
#     plt.plot(out_data)
#     plt.show()

#output_data = out_data

# %%
import QuantRegUtils as qru 
PATH = os.path.join(path + "/../models/BNN/")
MODEL_NAME = ""
loading = False
if loading:
    x_scales = np.load(PATH + MODEL_NAME + "x_scales.npy")
    x_offsets = np.load(PATH + MODEL_NAME + "x_offsets.npy")
    y_scale = np.load(PATH + MODEL_NAME + "y_scale.npy")
    y_offset = np.load(PATH + MODEL_NAME + "y_offset.npy")
    x_scaled = np.load(PATH + MODEL_NAME + "x_scaled.npy")
    y_scaled = np.load(PATH + MODEL_NAME + "y_scaled.npy")
else:
    x_scaled, x_scales, x_offsets = bf.do_scaling(input_data, -1, 1)
    y_offset, y_scale= bf.get_scale(output_data)

    y_scaled = bf.scale_data(output_data, y_offset, y_scale, -1,1)
    
    np.save(PATH + MODEL_NAME + "x_scales.npy", x_scales)
    np.save(PATH + MODEL_NAME + "x_offsets.npy", x_offsets)
    np.save(PATH + MODEL_NAME + "y_scale.npy", y_scale)
    np.save(PATH + MODEL_NAME + "y_offset.npy", y_offset)
    np.save(PATH + MODEL_NAME + "x_scaled.npy", x_scaled)
    np.save(PATH + MODEL_NAME + "y_scaled.npy", y_scaled)

x, y, scd = qru.scaling_and_dict(input_data, output_data)

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y[:,np.newaxis], test_size=0.2, random_state=42)

input_dict = {}
input_dict["train"] = X_train
input_dict["test"] = X_test

output_dict = {}
output_dict["train"] = y_train
output_dict["test"] = y_test

with open(PATH + "inputs.pkl", 'wb') as f:
    pickle.dump(input_dict, f, protocol=pickle.HIGHEST_PROTOCOL)

with open(PATH + "outputs.pkl", 'wb') as f:
    pickle.dump(output_dict, f, protocol=pickle.HIGHEST_PROTOCOL)
    
X_train, y_train = torch.tensor(X_train).float(), torch.tensor(y_train).float()
X_test, y_test = torch.tensor(X_test).float(), torch.tensor(y_test).float()

# %%
SAVEPATH = PATH 

LR = 0.01
LR0 = LR
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
regressor = BayesianRegressor(76, 1).to(device)
optimizer = optim.Adam(regressor.parameters(), lr = LR)
criterion = torch.nn.MSELoss()

# %%
ds_train = torch.utils.data.TensorDataset(X_train, y_train)
dataloader_train = torch.utils.data.DataLoader(ds_train, batch_size=2048, shuffle=True)

ds_test = torch.utils.data.TensorDataset(X_test, y_test)
dataloader_test = torch.utils.data.DataLoader(ds_test, batch_size=2048, shuffle=True)


CI = []
CIU = []
CIL = []
LRs = []

start = time.time()
iteration = 0
verbose = True
print("Started Training")
for epoch in range(400):
    
    if epoch%25==0:
        LR = LR*0.9
        LRs.append(LR)
        optimizer = optim.Adam(regressor.parameters(), lr = LR)
        print("Learning rate = " + str(LR))
    
    for i, (datapoints, labels) in enumerate(dataloader_train):
        optimizer.zero_grad()
        
        loss = regressor.sample_elbo(inputs=datapoints.to(device),
                           labels=labels.to(device),
                           criterion=criterion,
                           sample_nbr=3,
                           complexity_cost_weight=1/X_train.shape[0])
        loss.backward()
        optimizer.step()
        
        iteration += 1
        if iteration%100==0:
            #print("Epoch: " + str(epoch))
            ic_acc, under_ci_upper, over_ci_lower = evaluate_regression(regressor,
                                                                        X_test.to(device),
                                                                        y_test.to(device),
                                                                        samples=100,
                                                                        std_multiplier=2)
            CI.append(ic_acc)
            CIU.append(under_ci_upper)
            CIL.append(over_ci_lower)
            if verbose:
                print("CI acc: {:.4f}, CI upper acc: {:.4f}, CI lower acc: {:.4f}".format(ic_acc, under_ci_upper, over_ci_lower))
    
stop = time.time()
ic_acc, under_ci_upper, over_ci_lower = evaluate_regression(regressor,
                                                            X_test.to(device),
                                                            y_test.to(device),
                                                            samples=100,
                                                            std_multiplier=2) 
print("-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_")
print("Final Coverage and Loss")
print("CI acc: {:.4f}, CI upper acc: {:.4f}, CI lower acc: {:.4f}".format(ic_acc, under_ci_upper, over_ci_lower))
print("Loss: {:.4f}".format(loss))
print("Time to Complete = {:.2f} minutes".format(((stop-start)/60)))
print("-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_")

ci = np.array(CI)
ciu = np.array(CIU)
cil = np.array(CIL)

if PLOTTING:
    plt.figure(figsize = (16,9))
    plt.plot(100*ci, 'k', label = 'CI accuracy')
    plt.plot(100*ciu, 'r', label = 'CIUpper accuracy')
    plt.plot(100*cil, 'g', label = 'CILower accuracy')
    plt.plot(100*(LR/LR0), '.', label = 'LR')
    plt.ylabel("Percent Accuracy")
    plt.legend()
    plt.show()
# Out:
# Started Training
# Learning rate = 0.009000000000000001
# CI acc: 0.0306, CI upper acc: 0.4523, CI lower acc: 0.5783
# CI acc: 0.0476, CI upper acc: 0.7671, CI lower acc: 0.2805
# CI acc: 0.1041, CI upper acc: 0.6103, CI lower acc: 0.4939
# CI acc: 0.0854, CI upper acc: 0.3022, CI lower acc: 0.7832
# CI acc: 0.1107, CI upper acc: 0.3713, CI lower acc: 0.7393
# CI acc: 0.1708, CI upper acc: 0.6186, CI lower acc: 0.5522
# CI acc: 0.2294, CI upper acc: 0.6956, CI lower acc: 0.5338
# CI acc: 0.3103, CI upper acc: 0.7408, CI lower acc: 0.5694
# CI acc: 0.3175, CI upper acc: 0.6838, CI lower acc: 0.6338
# CI acc: 0.2484, CI upper acc: 0.4525, CI lower acc: 0.7960
# CI acc: 0.2479, CI upper acc: 0.4601, CI lower acc: 0.7878
# CI acc: 0.3952, CI upper acc: 0.6972, CI lower acc: 0.6981
# CI acc: 0.3181, CI upper acc: 0.5082, CI lower acc: 0.8099
# CI acc: 0.4140, CI upper acc: 0.6740, CI lower acc: 0.7400
# CI acc: 0.4567, CI upper acc: 0.7673, CI lower acc: 0.6894
# CI acc: 0.4771, CI upper acc: 0.7856, CI lower acc: 0.6915
# CI acc: 0.4622, CI upper acc: 0.6990, CI lower acc: 0.7631
# CI acc: 0.4608, CI upper acc: 0.7323, CI lower acc: 0.7285
# CI acc: 0.4034, CI upper acc: 0.5755, CI lower acc: 0.8279
# CI acc: 0.4415, CI upper acc: 0.6672, CI lower acc: 0.7742
# CI acc: 0.4614, CI upper acc: 0.6750, CI lower acc: 0.7865
# CI acc: 0.3407, CI upper acc: 0.4719, CI lower acc: 0.8688
# CI acc: 0.5222, CI upper acc: 0.8138, CI lower acc: 0.7085
# CI acc: 0.4319, CI upper acc: 0.6135, CI lower acc: 0.8184
# CI acc: 0.4772, CI upper acc: 0.7098, CI lower acc: 0.7674
# CI acc: 0.4890, CI upper acc: 0.6916, CI lower acc: 0.7973
# CI acc: 0.5522, CI upper acc: 0.7741, CI lower acc: 0.7781
# CI acc: 0.4991, CI upper acc: 0.7172, CI lower acc: 0.7820
# Learning rate = 0.008100000000000001
# CI acc: 0.3726, CI upper acc: 0.5299, CI lower acc: 0.8427
# CI acc: 0.5158, CI upper acc: 0.8277, CI lower acc: 0.6881
# CI acc: 0.5187, CI upper acc: 0.7306, CI lower acc: 0.7882
# CI acc: 0.4795, CI upper acc: 0.6678, CI lower acc: 0.8117
# CI acc: 0.4326, CI upper acc: 0.6562, CI lower acc: 0.7764
# CI acc: 0.5326, CI upper acc: 0.7365, CI lower acc: 0.7962
# CI acc: 0.5250, CI upper acc: 0.7619, CI lower acc: 0.7631
# CI acc: 0.4761, CI upper acc: 0.9050, CI lower acc: 0.5711
# CI acc: 0.5359, CI upper acc: 0.7336, CI lower acc: 0.8023
# CI acc: 0.4038, CI upper acc: 0.5503, CI lower acc: 0.8535
# CI acc: 0.4778, CI upper acc: 0.7326, CI lower acc: 0.7453
# CI acc: 0.4522, CI upper acc: 0.6218, CI lower acc: 0.8303
# CI acc: 0.5157, CI upper acc: 0.8602, CI lower acc: 0.6555
# CI acc: 0.5440, CI upper acc: 0.7581, CI lower acc: 0.7859
# CI acc: 0.5098, CI upper acc: 0.7759, CI lower acc: 0.7340
# CI acc: 0.4891, CI upper acc: 0.7580, CI lower acc: 0.7311
# CI acc: 0.4772, CI upper acc: 0.7127, CI lower acc: 0.7644
# CI acc: 0.5470, CI upper acc: 0.7787, CI lower acc: 0.7682
# CI acc: 0.4649, CI upper acc: 0.6423, CI lower acc: 0.8226
# CI acc: 0.3404, CI upper acc: 0.4417, CI lower acc: 0.8987
# CI acc: 0.5264, CI upper acc: 0.8431, CI lower acc: 0.6833
# CI acc: 0.5169, CI upper acc: 0.8971, CI lower acc: 0.6198
# CI acc: 0.5120, CI upper acc: 0.7200, CI lower acc: 0.7919
# CI acc: 0.5475, CI upper acc: 0.8100, CI lower acc: 0.7375
# CI acc: 0.5343, CI upper acc: 0.7506, CI lower acc: 0.7837
# CI acc: 0.4970, CI upper acc: 0.8495, CI lower acc: 0.6475
# CI acc: 0.5457, CI upper acc: 0.7212, CI lower acc: 0.8245
# CI acc: 0.5553, CI upper acc: 0.8056, CI lower acc: 0.7497
# Learning rate = 0.007290000000000001
# CI acc: 0.5011, CI upper acc: 0.6735, CI lower acc: 0.8276
# CI acc: 0.5137, CI upper acc: 0.7022, CI lower acc: 0.8115
# CI acc: 0.5592, CI upper acc: 0.7627, CI lower acc: 0.7965
# CI acc: 0.5882, CI upper acc: 0.8049, CI lower acc: 0.7833
# CI acc: 0.5522, CI upper acc: 0.8157, CI lower acc: 0.7365
# CI acc: 0.5264, CI upper acc: 0.7965, CI lower acc: 0.7299
# CI acc: 0.4988, CI upper acc: 0.6549, CI lower acc: 0.8439
# CI acc: 0.5125, CI upper acc: 0.6887, CI lower acc: 0.8238
# CI acc: 0.5521, CI upper acc: 0.7606, CI lower acc: 0.7915
# CI acc: 0.5911, CI upper acc: 0.8409, CI lower acc: 0.7502
# CI acc: 0.5479, CI upper acc: 0.7848, CI lower acc: 0.7630
# CI acc: 0.5527, CI upper acc: 0.7796, CI lower acc: 0.7731
# CI acc: 0.5630, CI upper acc: 0.8075, CI lower acc: 0.7556
# CI acc: 0.4139, CI upper acc: 0.5644, CI lower acc: 0.8495
# CI acc: 0.5429, CI upper acc: 0.7573, CI lower acc: 0.7856
# CI acc: 0.5845, CI upper acc: 0.7839, CI lower acc: 0.8006
# CI acc: 0.5515, CI upper acc: 0.7685, CI lower acc: 0.7830
# CI acc: 0.5593, CI upper acc: 0.7977, CI lower acc: 0.7615
# CI acc: 0.5837, CI upper acc: 0.8250, CI lower acc: 0.7587
# CI acc: 0.5280, CI upper acc: 0.7697, CI lower acc: 0.7583
# CI acc: 0.3964, CI upper acc: 0.5391, CI lower acc: 0.8573
# CI acc: 0.4887, CI upper acc: 0.6647, CI lower acc: 0.8241
# CI acc: 0.5378, CI upper acc: 0.7406, CI lower acc: 0.7972
# CI acc: 0.5466, CI upper acc: 0.7727, CI lower acc: 0.7739
# CI acc: 0.5339, CI upper acc: 0.8726, CI lower acc: 0.6613
# CI acc: 0.4988, CI upper acc: 0.7271, CI lower acc: 0.7717
# CI acc: 0.4797, CI upper acc: 0.7171, CI lower acc: 0.7626
# CI acc: 0.5313, CI upper acc: 0.7616, CI lower acc: 0.7697
# Learning rate = 0.006561000000000002
# CI acc: 0.5602, CI upper acc: 0.7641, CI lower acc: 0.7961
# CI acc: 0.5642, CI upper acc: 0.8051, CI lower acc: 0.7591
# CI acc: 0.4956, CI upper acc: 0.6699, CI lower acc: 0.8257
# CI acc: 0.3313, CI upper acc: 0.4654, CI lower acc: 0.8659
# CI acc: 0.5477, CI upper acc: 0.7896, CI lower acc: 0.7581
# CI acc: 0.5495, CI upper acc: 0.7842, CI lower acc: 0.7653
# CI acc: 0.4693, CI upper acc: 0.6372, CI lower acc: 0.8322
# CI acc: 0.5627, CI upper acc: 0.7998, CI lower acc: 0.7629
# CI acc: 0.5491, CI upper acc: 0.7830, CI lower acc: 0.7661
# CI acc: 0.5126, CI upper acc: 0.7752, CI lower acc: 0.7374
# CI acc: 0.5667, CI upper acc: 0.7742, CI lower acc: 0.7925
# CI acc: 0.5864, CI upper acc: 0.7781, CI lower acc: 0.8083
# CI acc: 0.5678, CI upper acc: 0.7590, CI lower acc: 0.8088
# CI acc: 0.5346, CI upper acc: 0.7363, CI lower acc: 0.7982
# CI acc: 0.5250, CI upper acc: 0.7320, CI lower acc: 0.7930
# CI acc: 0.5400, CI upper acc: 0.7530, CI lower acc: 0.7871
# CI acc: 0.5306, CI upper acc: 0.7273, CI lower acc: 0.8033
# CI acc: 0.5434, CI upper acc: 0.8487, CI lower acc: 0.6947
# CI acc: 0.5568, CI upper acc: 0.7563, CI lower acc: 0.8006
# CI acc: 0.5629, CI upper acc: 0.7606, CI lower acc: 0.8024
# CI acc: 0.5002, CI upper acc: 0.8040, CI lower acc: 0.6962
# CI acc: 0.5746, CI upper acc: 0.8077, CI lower acc: 0.7669
# CI acc: 0.4777, CI upper acc: 0.6261, CI lower acc: 0.8516
# CI acc: 0.5418, CI upper acc: 0.7549, CI lower acc: 0.7870
# CI acc: 0.5451, CI upper acc: 0.8130, CI lower acc: 0.7321
# CI acc: 0.4781, CI upper acc: 0.6385, CI lower acc: 0.8396
# CI acc: 0.5697, CI upper acc: 0.8313, CI lower acc: 0.7383
# CI acc: 0.5413, CI upper acc: 0.7612, CI lower acc: 0.7801
# Learning rate = 0.005904900000000002
# CI acc: 0.5291, CI upper acc: 0.8295, CI lower acc: 0.6996
# CI acc: 0.5015, CI upper acc: 0.6761, CI lower acc: 0.8253
# CI acc: 0.5596, CI upper acc: 0.7331, CI lower acc: 0.8265
# CI acc: 0.5302, CI upper acc: 0.7163, CI lower acc: 0.8139
# CI acc: 0.5013, CI upper acc: 0.6641, CI lower acc: 0.8372
# CI acc: 0.5527, CI upper acc: 0.8626, CI lower acc: 0.6900
# CI acc: 0.5835, CI upper acc: 0.8648, CI lower acc: 0.7186
# CI acc: 0.5478, CI upper acc: 0.7955, CI lower acc: 0.7524
# CI acc: 0.5523, CI upper acc: 0.8103, CI lower acc: 0.7420
# CI acc: 0.4880, CI upper acc: 0.6756, CI lower acc: 0.8124
# CI acc: 0.5953, CI upper acc: 0.8143, CI lower acc: 0.7810
# CI acc: 0.5606, CI upper acc: 0.7728, CI lower acc: 0.7878
# CI acc: 0.4907, CI upper acc: 0.6744, CI lower acc: 0.8163
# CI acc: 0.5480, CI upper acc: 0.7678, CI lower acc: 0.7803
# CI acc: 0.5367, CI upper acc: 0.7534, CI lower acc: 0.7834
# CI acc: 0.4831, CI upper acc: 0.6453, CI lower acc: 0.8378
# CI acc: 0.5032, CI upper acc: 0.6832, CI lower acc: 0.8200
# CI acc: 0.4911, CI upper acc: 0.6435, CI lower acc: 0.8476
# CI acc: 0.5087, CI upper acc: 0.7159, CI lower acc: 0.7928
# CI acc: 0.5292, CI upper acc: 0.6949, CI lower acc: 0.8344
# CI acc: 0.5071, CI upper acc: 0.7697, CI lower acc: 0.7374
# CI acc: 0.5514, CI upper acc: 0.7992, CI lower acc: 0.7522
# CI acc: 0.5483, CI upper acc: 0.7960, CI lower acc: 0.7523
# CI acc: 0.5323, CI upper acc: 0.7413, CI lower acc: 0.7910
# CI acc: 0.5315, CI upper acc: 0.7572, CI lower acc: 0.7742
# CI acc: 0.5445, CI upper acc: 0.8655, CI lower acc: 0.6790
# CI acc: 0.5497, CI upper acc: 0.7540, CI lower acc: 0.7957
# CI acc: 0.5245, CI upper acc: 0.7243, CI lower acc: 0.8002
# Learning rate = 0.005314410000000002
# CI acc: 0.5600, CI upper acc: 0.7297, CI lower acc: 0.8303
# CI acc: 0.6189, CI upper acc: 0.8867, CI lower acc: 0.7322
# CI acc: 0.5699, CI upper acc: 0.8498, CI lower acc: 0.7201
# CI acc: 0.4509, CI upper acc: 0.6238, CI lower acc: 0.8271
# CI acc: 0.5197, CI upper acc: 0.6847, CI lower acc: 0.8351
# CI acc: 0.5747, CI upper acc: 0.8137, CI lower acc: 0.7610
# CI acc: 0.5655, CI upper acc: 0.7913, CI lower acc: 0.7742
# CI acc: 0.5445, CI upper acc: 0.8130, CI lower acc: 0.7315
# CI acc: 0.5593, CI upper acc: 0.8210, CI lower acc: 0.7383
# CI acc: 0.4636, CI upper acc: 0.6340, CI lower acc: 0.8296
# CI acc: 0.5199, CI upper acc: 0.7274, CI lower acc: 0.7925
# CI acc: 0.5756, CI upper acc: 0.7530, CI lower acc: 0.8226
# CI acc: 0.5304, CI upper acc: 0.8805, CI lower acc: 0.6499
# CI acc: 0.5529, CI upper acc: 0.7543, CI lower acc: 0.7986
# CI acc: 0.5408, CI upper acc: 0.8391, CI lower acc: 0.7017
# CI acc: 0.5397, CI upper acc: 0.7780, CI lower acc: 0.7617
# CI acc: 0.5306, CI upper acc: 0.7063, CI lower acc: 0.8242
# CI acc: 0.4399, CI upper acc: 0.5645, CI lower acc: 0.8754
# CI acc: 0.5892, CI upper acc: 0.8506, CI lower acc: 0.7386
# CI acc: 0.5471, CI upper acc: 0.7662, CI lower acc: 0.7809
# CI acc: 0.5563, CI upper acc: 0.7967, CI lower acc: 0.7596
# CI acc: 0.5732, CI upper acc: 0.7907, CI lower acc: 0.7825
# CI acc: 0.5641, CI upper acc: 0.7627, CI lower acc: 0.8013
# CI acc: 0.4287, CI upper acc: 0.5625, CI lower acc: 0.8663
# CI acc: 0.5785, CI upper acc: 0.8014, CI lower acc: 0.7771
# CI acc: 0.5437, CI upper acc: 0.8097, CI lower acc: 0.7340
# CI acc: 0.5636, CI upper acc: 0.7525, CI lower acc: 0.8111
# CI acc: 0.5365, CI upper acc: 0.7360, CI lower acc: 0.8005
# Learning rate = 0.004782969000000002
# CI acc: 0.5661, CI upper acc: 0.7497, CI lower acc: 0.8163
# CI acc: 0.5865, CI upper acc: 0.7950, CI lower acc: 0.7915
# CI acc: 0.5076, CI upper acc: 0.6548, CI lower acc: 0.8528
# CI acc: 0.6033, CI upper acc: 0.8271, CI lower acc: 0.7762
# CI acc: 0.5439, CI upper acc: 0.7110, CI lower acc: 0.8329
# CI acc: 0.5509, CI upper acc: 0.7719, CI lower acc: 0.7791
# CI acc: 0.5803, CI upper acc: 0.7803, CI lower acc: 0.8001
# CI acc: 0.5860, CI upper acc: 0.7975, CI lower acc: 0.7884
# CI acc: 0.5448, CI upper acc: 0.7442, CI lower acc: 0.8006
# CI acc: 0.5162, CI upper acc: 0.6776, CI lower acc: 0.8386
# CI acc: 0.4831, CI upper acc: 0.6318, CI lower acc: 0.8512
# CI acc: 0.5359, CI upper acc: 0.7275, CI lower acc: 0.8084
# CI acc: 0.3593, CI upper acc: 0.4751, CI lower acc: 0.8842
# CI acc: 0.5408, CI upper acc: 0.7386, CI lower acc: 0.8023
# CI acc: 0.5500, CI upper acc: 0.7758, CI lower acc: 0.7742
# CI acc: 0.5370, CI upper acc: 0.8310, CI lower acc: 0.7060
# CI acc: 0.5430, CI upper acc: 0.7835, CI lower acc: 0.7595
# CI acc: 0.5068, CI upper acc: 0.7120, CI lower acc: 0.7948
# CI acc: 0.4969, CI upper acc: 0.6545, CI lower acc: 0.8424
# CI acc: 0.5229, CI upper acc: 0.6892, CI lower acc: 0.8337
# CI acc: 0.5239, CI upper acc: 0.7285, CI lower acc: 0.7954
# CI acc: 0.5299, CI upper acc: 0.6962, CI lower acc: 0.8337
# CI acc: 0.5408, CI upper acc: 0.7126, CI lower acc: 0.8282
# CI acc: 0.4563, CI upper acc: 0.5884, CI lower acc: 0.8678
# CI acc: 0.5318, CI upper acc: 0.7293, CI lower acc: 0.8025
# CI acc: 0.5547, CI upper acc: 0.7811, CI lower acc: 0.7735
# CI acc: 0.5392, CI upper acc: 0.7415, CI lower acc: 0.7977
# CI acc: 0.5625, CI upper acc: 0.7742, CI lower acc: 0.7882
# Learning rate = 0.004304672100000002
# CI acc: 0.5700, CI upper acc: 0.7570, CI lower acc: 0.8130
# CI acc: 0.5865, CI upper acc: 0.8568, CI lower acc: 0.7296
# CI acc: 0.5845, CI upper acc: 0.8209, CI lower acc: 0.7636
# CI acc: 0.5624, CI upper acc: 0.7959, CI lower acc: 0.7665
# CI acc: 0.5515, CI upper acc: 0.7397, CI lower acc: 0.8118
# CI acc: 0.5600, CI upper acc: 0.7631, CI lower acc: 0.7969
# CI acc: 0.5305, CI upper acc: 0.7112, CI lower acc: 0.8193
# CI acc: 0.5550, CI upper acc: 0.7356, CI lower acc: 0.8194
# CI acc: 0.5380, CI upper acc: 0.7171, CI lower acc: 0.8209
# CI acc: 0.5680, CI upper acc: 0.8544, CI lower acc: 0.7135
# CI acc: 0.5754, CI upper acc: 0.7571, CI lower acc: 0.8183
# CI acc: 0.5692, CI upper acc: 0.7957, CI lower acc: 0.7735
# CI acc: 0.5683, CI upper acc: 0.8215, CI lower acc: 0.7468
# CI acc: 0.5834, CI upper acc: 0.7716, CI lower acc: 0.8117
# CI acc: 0.5625, CI upper acc: 0.7531, CI lower acc: 0.8095
# CI acc: 0.5449, CI upper acc: 0.7285, CI lower acc: 0.8164
# CI acc: 0.5215, CI upper acc: 0.7884, CI lower acc: 0.7331
# CI acc: 0.5439, CI upper acc: 0.8339, CI lower acc: 0.7100
# CI acc: 0.5396, CI upper acc: 0.7191, CI lower acc: 0.8204
# CI acc: 0.5557, CI upper acc: 0.7939, CI lower acc: 0.7618
# CI acc: 0.5366, CI upper acc: 0.8012, CI lower acc: 0.7354
# CI acc: 0.4851, CI upper acc: 0.6409, CI lower acc: 0.8442
# CI acc: 0.5237, CI upper acc: 0.7428, CI lower acc: 0.7809
# CI acc: 0.5469, CI upper acc: 0.7849, CI lower acc: 0.7621
# CI acc: 0.5412, CI upper acc: 0.7248, CI lower acc: 0.8164
# CI acc: 0.4544, CI upper acc: 0.6112, CI lower acc: 0.8432
# CI acc: 0.5416, CI upper acc: 0.7276, CI lower acc: 0.8141
# CI acc: 0.5640, CI upper acc: 0.7942, CI lower acc: 0.7698
# Learning rate = 0.003874204890000002
# CI acc: 0.5708, CI upper acc: 0.7849, CI lower acc: 0.7860
# CI acc: 0.5778, CI upper acc: 0.7697, CI lower acc: 0.8081
# CI acc: 0.5073, CI upper acc: 0.6902, CI lower acc: 0.8170
# CI acc: 0.5540, CI upper acc: 0.7695, CI lower acc: 0.7845
# CI acc: 0.5912, CI upper acc: 0.8039, CI lower acc: 0.7873
# CI acc: 0.5658, CI upper acc: 0.8198, CI lower acc: 0.7461
# CI acc: 0.5433, CI upper acc: 0.7221, CI lower acc: 0.8212
# CI acc: 0.5518, CI upper acc: 0.8803, CI lower acc: 0.6715
# CI acc: 0.5386, CI upper acc: 0.7037, CI lower acc: 0.8349
# CI acc: 0.5956, CI upper acc: 0.8083, CI lower acc: 0.7873
# CI acc: 0.5652, CI upper acc: 0.7412, CI lower acc: 0.8240
# CI acc: 0.5217, CI upper acc: 0.6782, CI lower acc: 0.8435
# CI acc: 0.5840, CI upper acc: 0.7859, CI lower acc: 0.7981
# CI acc: 0.5926, CI upper acc: 0.8052, CI lower acc: 0.7875
# CI acc: 0.5551, CI upper acc: 0.8078, CI lower acc: 0.7473
# CI acc: 0.5503, CI upper acc: 0.7630, CI lower acc: 0.7873
# CI acc: 0.4951, CI upper acc: 0.6744, CI lower acc: 0.8206
# CI acc: 0.5830, CI upper acc: 0.8162, CI lower acc: 0.7668
# CI acc: 0.5297, CI upper acc: 0.6874, CI lower acc: 0.8423
# CI acc: 0.5920, CI upper acc: 0.8152, CI lower acc: 0.7768
# CI acc: 0.5728, CI upper acc: 0.8063, CI lower acc: 0.7665
# CI acc: 0.5545, CI upper acc: 0.7344, CI lower acc: 0.8201
# CI acc: 0.5411, CI upper acc: 0.7427, CI lower acc: 0.7984
# CI acc: 0.5598, CI upper acc: 0.8535, CI lower acc: 0.7062
# CI acc: 0.5447, CI upper acc: 0.7486, CI lower acc: 0.7961
# CI acc: 0.5712, CI upper acc: 0.8081, CI lower acc: 0.7631
# CI acc: 0.5526, CI upper acc: 0.8523, CI lower acc: 0.7003
# CI acc: 0.5505, CI upper acc: 0.7291, CI lower acc: 0.8214
# Learning rate = 0.003486784401000002
# CI acc: 0.5690, CI upper acc: 0.7508, CI lower acc: 0.8182
# CI acc: 0.5912, CI upper acc: 0.8306, CI lower acc: 0.7606
# CI acc: 0.4888, CI upper acc: 0.6519, CI lower acc: 0.8369
# CI acc: 0.5383, CI upper acc: 0.7206, CI lower acc: 0.8177
# CI acc: 0.5660, CI upper acc: 0.7797, CI lower acc: 0.7863
# CI acc: 0.5676, CI upper acc: 0.7929, CI lower acc: 0.7747
# CI acc: 0.5792, CI upper acc: 0.8354, CI lower acc: 0.7438
# CI acc: 0.4994, CI upper acc: 0.6546, CI lower acc: 0.8448
# CI acc: 0.5123, CI upper acc: 0.6983, CI lower acc: 0.8141
# CI acc: 0.5179, CI upper acc: 0.6904, CI lower acc: 0.8275
# CI acc: 0.5642, CI upper acc: 0.7918, CI lower acc: 0.7725
# CI acc: 0.5748, CI upper acc: 0.7781, CI lower acc: 0.7967
# CI acc: 0.4621, CI upper acc: 0.6151, CI lower acc: 0.8470
# CI acc: 0.5254, CI upper acc: 0.7302, CI lower acc: 0.7952
# CI acc: 0.5221, CI upper acc: 0.7374, CI lower acc: 0.7847
# CI acc: 0.5181, CI upper acc: 0.7065, CI lower acc: 0.8116
# CI acc: 0.5494, CI upper acc: 0.7526, CI lower acc: 0.7968
# CI acc: 0.5313, CI upper acc: 0.7012, CI lower acc: 0.8301
# CI acc: 0.5465, CI upper acc: 0.7333, CI lower acc: 0.8131
# CI acc: 0.5758, CI upper acc: 0.7878, CI lower acc: 0.7880
# CI acc: 0.5640, CI upper acc: 0.7712, CI lower acc: 0.7928
# CI acc: 0.5471, CI upper acc: 0.8216, CI lower acc: 0.7255
# CI acc: 0.5741, CI upper acc: 0.8314, CI lower acc: 0.7427
# CI acc: 0.5449, CI upper acc: 0.7837, CI lower acc: 0.7612
# CI acc: 0.5686, CI upper acc: 0.7798, CI lower acc: 0.7889
# CI acc: 0.5838, CI upper acc: 0.7839, CI lower acc: 0.8000
# CI acc: 0.5587, CI upper acc: 0.7465, CI lower acc: 0.8122
# CI acc: 0.5397, CI upper acc: 0.7214, CI lower acc: 0.8182
# Learning rate = 0.003138105960900002
# CI acc: 0.5466, CI upper acc: 0.7670, CI lower acc: 0.7797
# CI acc: 0.5966, CI upper acc: 0.8257, CI lower acc: 0.7709
# CI acc: 0.5953, CI upper acc: 0.8011, CI lower acc: 0.7942
# CI acc: 0.5460, CI upper acc: 0.7239, CI lower acc: 0.8222
# CI acc: 0.5832, CI upper acc: 0.7483, CI lower acc: 0.8349
# CI acc: 0.5835, CI upper acc: 0.8209, CI lower acc: 0.7626
# CI acc: 0.5692, CI upper acc: 0.7609, CI lower acc: 0.8082
# CI acc: 0.5063, CI upper acc: 0.6667, CI lower acc: 0.8396
# CI acc: 0.5861, CI upper acc: 0.8113, CI lower acc: 0.7748
# CI acc: 0.5266, CI upper acc: 0.7899, CI lower acc: 0.7367
# CI acc: 0.5768, CI upper acc: 0.8095, CI lower acc: 0.7674
# CI acc: 0.5831, CI upper acc: 0.8007, CI lower acc: 0.7824
# CI acc: 0.5556, CI upper acc: 0.7497, CI lower acc: 0.8059
# CI acc: 0.5667, CI upper acc: 0.7365, CI lower acc: 0.8302
# CI acc: 0.5644, CI upper acc: 0.7547, CI lower acc: 0.8097
# CI acc: 0.5715, CI upper acc: 0.7767, CI lower acc: 0.7948
# CI acc: 0.4999, CI upper acc: 0.6579, CI lower acc: 0.8420
# CI acc: 0.5542, CI upper acc: 0.7955, CI lower acc: 0.7587
# CI acc: 0.5402, CI upper acc: 0.8243, CI lower acc: 0.7159
# CI acc: 0.5647, CI upper acc: 0.8704, CI lower acc: 0.6943
# CI acc: 0.5784, CI upper acc: 0.8415, CI lower acc: 0.7369
# CI acc: 0.5887, CI upper acc: 0.8317, CI lower acc: 0.7570
# CI acc: 0.5362, CI upper acc: 0.7314, CI lower acc: 0.8048
# CI acc: 0.5670, CI upper acc: 0.7478, CI lower acc: 0.8192
# CI acc: 0.5690, CI upper acc: 0.7482, CI lower acc: 0.8208
# CI acc: 0.4879, CI upper acc: 0.6705, CI lower acc: 0.8174
# CI acc: 0.5784, CI upper acc: 0.8055, CI lower acc: 0.7728
# CI acc: 0.5655, CI upper acc: 0.7918, CI lower acc: 0.7737
# Learning rate = 0.0028242953648100018
# CI acc: 0.6066, CI upper acc: 0.8484, CI lower acc: 0.7581
# CI acc: 0.5474, CI upper acc: 0.7388, CI lower acc: 0.8086
# CI acc: 0.5734, CI upper acc: 0.7856, CI lower acc: 0.7878
# CI acc: 0.5572, CI upper acc: 0.7993, CI lower acc: 0.7579
# CI acc: 0.5403, CI upper acc: 0.7303, CI lower acc: 0.8099
# CI acc: 0.5829, CI upper acc: 0.7911, CI lower acc: 0.7918
# CI acc: 0.5462, CI upper acc: 0.7303, CI lower acc: 0.8159
# CI acc: 0.5812, CI upper acc: 0.8117, CI lower acc: 0.7695
# CI acc: 0.5730, CI upper acc: 0.8530, CI lower acc: 0.7200
# CI acc: 0.5768, CI upper acc: 0.8037, CI lower acc: 0.7731
# CI acc: 0.5317, CI upper acc: 0.7045, CI lower acc: 0.8271
# CI acc: 0.5787, CI upper acc: 0.8105, CI lower acc: 0.7682
# CI acc: 0.5662, CI upper acc: 0.7717, CI lower acc: 0.7945
# CI acc: 0.5778, CI upper acc: 0.8131, CI lower acc: 0.7647
# CI acc: 0.5724, CI upper acc: 0.7529, CI lower acc: 0.8195
# CI acc: 0.5375, CI upper acc: 0.7169, CI lower acc: 0.8206
# CI acc: 0.5503, CI upper acc: 0.7478, CI lower acc: 0.8024
# CI acc: 0.5878, CI upper acc: 0.8174, CI lower acc: 0.7704
# CI acc: 0.5771, CI upper acc: 0.7628, CI lower acc: 0.8143
# CI acc: 0.5653, CI upper acc: 0.7751, CI lower acc: 0.7903
# CI acc: 0.5688, CI upper acc: 0.8102, CI lower acc: 0.7586
# CI acc: 0.5357, CI upper acc: 0.7143, CI lower acc: 0.8214
# CI acc: 0.5861, CI upper acc: 0.8358, CI lower acc: 0.7503
# CI acc: 0.5855, CI upper acc: 0.7939, CI lower acc: 0.7916
# CI acc: 0.5529, CI upper acc: 0.7231, CI lower acc: 0.8297
# CI acc: 0.5828, CI upper acc: 0.8011, CI lower acc: 0.7817
# CI acc: 0.5644, CI upper acc: 0.8402, CI lower acc: 0.7242
# CI acc: 0.5940, CI upper acc: 0.8383, CI lower acc: 0.7557
# Learning rate = 0.0025418658283290017
# CI acc: 0.5720, CI upper acc: 0.7619, CI lower acc: 0.8101
# CI acc: 0.5922, CI upper acc: 0.8072, CI lower acc: 0.7850
# CI acc: 0.5504, CI upper acc: 0.7335, CI lower acc: 0.8169
# CI acc: 0.5768, CI upper acc: 0.8594, CI lower acc: 0.7174
# CI acc: 0.5902, CI upper acc: 0.7861, CI lower acc: 0.8040
# CI acc: 0.5722, CI upper acc: 0.8314, CI lower acc: 0.7407
# CI acc: 0.4569, CI upper acc: 0.6064, CI lower acc: 0.8505
# CI acc: 0.5814, CI upper acc: 0.7773, CI lower acc: 0.8041
# CI acc: 0.5664, CI upper acc: 0.7629, CI lower acc: 0.8035
# CI acc: 0.5709, CI upper acc: 0.7896, CI lower acc: 0.7813
# CI acc: 0.5862, CI upper acc: 0.7942, CI lower acc: 0.7920
# CI acc: 0.5554, CI upper acc: 0.7725, CI lower acc: 0.7829
# CI acc: 0.5768, CI upper acc: 0.8223, CI lower acc: 0.7545
# CI acc: 0.5899, CI upper acc: 0.8135, CI lower acc: 0.7764
# CI acc: 0.5361, CI upper acc: 0.7162, CI lower acc: 0.8199
# CI acc: 0.5382, CI upper acc: 0.7095, CI lower acc: 0.8287
# CI acc: 0.6107, CI upper acc: 0.8279, CI lower acc: 0.7828
# CI acc: 0.5826, CI upper acc: 0.8149, CI lower acc: 0.7678
# CI acc: 0.5665, CI upper acc: 0.7888, CI lower acc: 0.7776
# CI acc: 0.5292, CI upper acc: 0.7148, CI lower acc: 0.8143
# CI acc: 0.5448, CI upper acc: 0.7588, CI lower acc: 0.7861
# CI acc: 0.5773, CI upper acc: 0.7603, CI lower acc: 0.8170
# CI acc: 0.6051, CI upper acc: 0.8293, CI lower acc: 0.7758
# CI acc: 0.5300, CI upper acc: 0.7005, CI lower acc: 0.8295
# CI acc: 0.5512, CI upper acc: 0.7442, CI lower acc: 0.8070
# CI acc: 0.5472, CI upper acc: 0.7715, CI lower acc: 0.7757
# CI acc: 0.5067, CI upper acc: 0.6683, CI lower acc: 0.8384
# CI acc: 0.5687, CI upper acc: 0.7852, CI lower acc: 0.7835
# Learning rate = 0.0022876792454961017
# CI acc: 0.5722, CI upper acc: 0.7668, CI lower acc: 0.8054
# CI acc: 0.4853, CI upper acc: 0.6326, CI lower acc: 0.8528
# CI acc: 0.5957, CI upper acc: 0.7954, CI lower acc: 0.8003
# CI acc: 0.5896, CI upper acc: 0.8181, CI lower acc: 0.7715
# CI acc: 0.5558, CI upper acc: 0.7654, CI lower acc: 0.7903
# CI acc: 0.5051, CI upper acc: 0.6726, CI lower acc: 0.8325
# CI acc: 0.5745, CI upper acc: 0.8548, CI lower acc: 0.7197
# CI acc: 0.5501, CI upper acc: 0.7381, CI lower acc: 0.8120
# CI acc: 0.5705, CI upper acc: 0.7727, CI lower acc: 0.7978
# CI acc: 0.5337, CI upper acc: 0.7204, CI lower acc: 0.8132
# CI acc: 0.5583, CI upper acc: 0.7319, CI lower acc: 0.8264
# CI acc: 0.5340, CI upper acc: 0.6929, CI lower acc: 0.8411
# CI acc: 0.5590, CI upper acc: 0.8420, CI lower acc: 0.7170
# CI acc: 0.5714, CI upper acc: 0.7985, CI lower acc: 0.7729
# CI acc: 0.5827, CI upper acc: 0.7907, CI lower acc: 0.7920
# CI acc: 0.5920, CI upper acc: 0.8027, CI lower acc: 0.7893
# CI acc: 0.5602, CI upper acc: 0.7274, CI lower acc: 0.8328
# CI acc: 0.5698, CI upper acc: 0.7633, CI lower acc: 0.8065
# CI acc: 0.5665, CI upper acc: 0.7537, CI lower acc: 0.8128
# CI acc: 0.5661, CI upper acc: 0.7562, CI lower acc: 0.8098
# CI acc: 0.5544, CI upper acc: 0.7579, CI lower acc: 0.7965
# Learning rate = 0.0020589113209464917
# CI acc: 0.5613, CI upper acc: 0.7444, CI lower acc: 0.8169
# CI acc: 0.5035, CI upper acc: 0.6612, CI lower acc: 0.8423
# CI acc: 0.6009, CI upper acc: 0.8103, CI lower acc: 0.7905
# CI acc: 0.5979, CI upper acc: 0.8391, CI lower acc: 0.7587
# CI acc: 0.5653, CI upper acc: 0.7499, CI lower acc: 0.8154
# CI acc: 0.5543, CI upper acc: 0.7483, CI lower acc: 0.8060
# CI acc: 0.5856, CI upper acc: 0.8156, CI lower acc: 0.7700
# CI acc: 0.5506, CI upper acc: 0.7428, CI lower acc: 0.8078
# CI acc: 0.5637, CI upper acc: 0.7500, CI lower acc: 0.8137
# CI acc: 0.5598, CI upper acc: 0.7797, CI lower acc: 0.7801
# CI acc: 0.5602, CI upper acc: 0.7483, CI lower acc: 0.8119
# CI acc: 0.5837, CI upper acc: 0.7910, CI lower acc: 0.7926
# CI acc: 0.5867, CI upper acc: 0.8071, CI lower acc: 0.7796
# CI acc: 0.5466, CI upper acc: 0.7321, CI lower acc: 0.8144
# CI acc: 0.5298, CI upper acc: 0.7023, CI lower acc: 0.8275
# CI acc: 0.5638, CI upper acc: 0.7580, CI lower acc: 0.8058
# CI acc: 0.5237, CI upper acc: 0.6897, CI lower acc: 0.8340
# CI acc: 0.5677, CI upper acc: 0.7862, CI lower acc: 0.7815
# CI acc: 0.5273, CI upper acc: 0.7140, CI lower acc: 0.8133
# CI acc: 0.5866, CI upper acc: 0.7933, CI lower acc: 0.7934
# CI acc: 0.5744, CI upper acc: 0.7738, CI lower acc: 0.8006
# CI acc: 0.5579, CI upper acc: 0.7373, CI lower acc: 0.8206
# CI acc: 0.5811, CI upper acc: 0.8162, CI lower acc: 0.7648
# CI acc: 0.5796, CI upper acc: 0.8445, CI lower acc: 0.7351
# CI acc: 0.5954, CI upper acc: 0.8321, CI lower acc: 0.7633
# CI acc: 0.5283, CI upper acc: 0.7139, CI lower acc: 0.8144
# CI acc: 0.5760, CI upper acc: 0.7768, CI lower acc: 0.7991
# CI acc: 0.5704, CI upper acc: 0.7617, CI lower acc: 0.8087
# Learning rate = 0.0018530201888518425
# CI acc: 0.5913, CI upper acc: 0.8139, CI lower acc: 0.7774
# CI acc: 0.5724, CI upper acc: 0.7973, CI lower acc: 0.7751
# CI acc: 0.5733, CI upper acc: 0.7883, CI lower acc: 0.7850
# CI acc: 0.5945, CI upper acc: 0.8006, CI lower acc: 0.7939
# CI acc: 0.5640, CI upper acc: 0.7485, CI lower acc: 0.8155
# CI acc: 0.5686, CI upper acc: 0.7794, CI lower acc: 0.7892
# CI acc: 0.5273, CI upper acc: 0.6842, CI lower acc: 0.8432
# CI acc: 0.5361, CI upper acc: 0.7141, CI lower acc: 0.8220
# CI acc: 0.5790, CI upper acc: 0.8175, CI lower acc: 0.7615
# CI acc: 0.5346, CI upper acc: 0.7048, CI lower acc: 0.8297
# CI acc: 0.5615, CI upper acc: 0.7620, CI lower acc: 0.7994
# CI acc: 0.5963, CI upper acc: 0.7997, CI lower acc: 0.7966
# CI acc: 0.5955, CI upper acc: 0.8018, CI lower acc: 0.7937
# CI acc: 0.5495, CI upper acc: 0.7275, CI lower acc: 0.8220
# CI acc: 0.5725, CI upper acc: 0.8126, CI lower acc: 0.7599
# CI acc: 0.5766, CI upper acc: 0.7972, CI lower acc: 0.7794
# CI acc: 0.5486, CI upper acc: 0.7338, CI lower acc: 0.8149
# CI acc: 0.5700, CI upper acc: 0.7901, CI lower acc: 0.7799
# CI acc: 0.5419, CI upper acc: 0.7206, CI lower acc: 0.8213
# CI acc: 0.5615, CI upper acc: 0.7362, CI lower acc: 0.8253
# CI acc: 0.5219, CI upper acc: 0.6882, CI lower acc: 0.8338
# CI acc: 0.5718, CI upper acc: 0.7882, CI lower acc: 0.7836
# CI acc: 0.5761, CI upper acc: 0.7930, CI lower acc: 0.7831
# CI acc: 0.5790, CI upper acc: 0.7886, CI lower acc: 0.7904
# CI acc: 0.5647, CI upper acc: 0.7738, CI lower acc: 0.7909
# CI acc: 0.5619, CI upper acc: 0.7583, CI lower acc: 0.8036
# CI acc: 0.5595, CI upper acc: 0.7623, CI lower acc: 0.7972
# CI acc: 0.5278, CI upper acc: 0.6916, CI lower acc: 0.8362
# -_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_
# Final Coverage and Loss
# CI acc: 0.5408, CI upper acc: 0.6998, CI lower acc: 0.8410
# Loss: 0.0541
# Time to Complete = 1.85 minutes
# -_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_

# %%
num=100
tempnum=y_test.shape[0]
preds=np.zeros((tempnum,num))
for i in range(num):
    temp=regressor.forward(X_test.cuda())
    pred1=temp.cpu().detach().numpy()
    preds[:,i]=pred1[:,0]
tempmean=np.mean(preds,axis=1)

tempstd=np.std(preds,axis=1)
tempmean.shape,tempstd.shape
tempmedian=np.quantile(preds,0.5,axis=1)
temp075=np.quantile(preds,0.975,axis=1)
temp025=np.quantile(preds,0.025,axis=1)


yreals = bf.unscale_data(y_test, y_offset, y_scale, -1, 1)
ymedian=bf.unscale_data(tempmedian[:,np.newaxis], y_offset, y_scale, -1, 1)
yu=bf.unscale_data(temp075[:,np.newaxis], y_offset, y_scale, -1, 1)
yl=bf.unscale_data(temp025[:,np.newaxis], y_offset, y_scale, -1, 1)


idx=np.argsort(ymedian[:,0])
base=np.arange(len(idx))
lower=yl[idx,0]
upper=yu[idx,0]

markersize = 15
plt.figure(figsize=(30,10))
#plt.title("BNN Results: Uncertainty Estimates and Mean Prediction for FEL Pulse Energy")
plt.plot(yreals[idx,0],'x', color = colors[0], alpha = 0.75, markersize = markersize, label= "Measurement")
plt.plot(yu[idx,0],'.-', color = colors[2], markersize = markersize,label = "Upper Bound")
plt.plot(yl[idx,0],'.-', color = colors[2], markersize = markersize,label = "Lower Bound")
plt.plot(ymedian[idx,0],'.', color = colors[1],markersize = markersize,label= "BNN Mean Prediction")
plt.fill_between(base,lower,upper,color = colors[2], alpha=0.3,label="$95$ Percentile Confidence Interval") 
plt.ylim(-0.25,5)
plt.xlabel('Sample Index')
plt.ylabel('Pulse Energy (mJ)')
plt.legend(prop={'size': 14})
#plt.savefig("BNN-test-sortedmed2.png")
plt.show()

coverage = np.logical_and(yreals[idx,0].numpy()>yl[idx,0],yreals[idx,0].numpy()<yu[idx,0])
coverage = np.array([int(elem) for elem in coverage])
coverage_percent = 100*np.sum(coverage)/len(ymedian[idx,0])

print("The percent of measured values within the confidence interval is: {:2.2f}%".format(coverage_percent))

lbinds = np.argsort(yl[:,0])
ubinds = np.argsort(yu[:,0])

n = 500
seq = []
step = int(yu.shape[0]/n)

for i in range(n):
        temp1=lbinds[i*step:(i+1)*step]
        temp2=ubinds[i*step:(i+1)*step]
        for num in temp1:
            if(num in temp2):
                seq.append(num)
                break
                

base=np.arange(len(seq))
lower=yl[seq,0]
upper=yu[seq,0]

plt.figure(figsize=(30,10))
#plt.title("BNN Results Mean Prediction and Uncertainty Estimates for FEL Pulse Energy, For Data Test Set Only")
plt.plot(yu[seq,0],'.-', color = colors[2], markersize = markersize,label = "Upper Bound")
plt.plot(yl[seq,0],'.-', color = colors[2], markersize = markersize,label = "Lower Bound")

plt.plot(yreals[seq,0],'x', color = colors[0], alpha = 0.75, markersize = markersize,label= "Measurement")
plt.plot(ymedian[seq,0],'.', color = colors[1],markersize = markersize,label= "BNN Mean Prediction")

plt.fill_between(base,lower,upper, color = colors[2], alpha=0.3,label="$95$ Percentile Confidence Interval") 

plt.xlabel('Sample Index')
plt.ylabel('Pulse Energy (mJ)')
plt.legend(prop={'size': 14})
plt.ylim(-0.25,5)
#plt.savefig("BNN-test-sortedseq2.png")
plt.show()




mse, mae = calc_mse_and_mae(yreals.detach().numpy(), ymedian)
print("MSE = {:2.2f}".format(mse))
print("MAE = {:2.2f}".format(mae))

torch.save(regressor.state_dict(), SAVEPATH + "BNN_model.h5")
# Out:
# The percent of measured values within the confidence interval is: 47.61%
# MSE = 0.19
# MAE = 0.31
